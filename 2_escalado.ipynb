# %% [markdown]
# # Escalado
# Conjunto de datos: iris (incluido en sklearn)
# Este conjunto de datos es compacto y perfecto para demostrar técnicas de escalado.

# %%
# Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
iris = load_iris(as_frame=True)
data = iris.data

# %%
# Visualizar las estadísticas iniciales
print("Estadísticas iniciales:")
data.describe()
# Out:
# Estadísticas iniciales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Aplicar MinMaxScaler
minmax_scaler = MinMaxScaler()
data_minmax = pd.DataFrame(minmax_scaler.fit_transform(data), columns=data.columns)

# %%
# Aplicar StandardScaler
standard_scaler = StandardScaler()
data_standard = pd.DataFrame(standard_scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado. Crea gráficas en donde veas correcto.

# %% [markdown]
# ### 1. ¿Qué diferencias encuentras entre las estadísticas originales y las del escalado MinMax?

# %%
print("--- Estadísticas Originales ---")
display(data.describe())

print("\n--- Estadísticas MinMaxScaler ---")
display(data_minmax.describe())
# Out:
# --- Estadísticas Originales ---
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
# --- Estadísticas MinMaxScaler ---
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...

# %% [markdown]
# ### 2. Crea una gráfica de la distribución de la variable 'sepal length (cm)' antes y después del escalado.

# %%
# Configurar la figura con 3 subgráficos
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Gráfica de datos originales
sns.histplot(data['sepal length (cm)'], kde=True, ax=axes[0], color='blue')
axes[0].set_title('Original (medidas en cm)')

# Gráfica de datos con MinMaxScaler
sns.histplot(data_minmax['sepal length (cm)'], kde=True, ax=axes[1], color='green')
axes[1].set_title('MinMaxScaler (Rango 0 a 1)')

# Gráfica de datos con StandardScaler
sns.histplot(data_standard['sepal length (cm)'], kde=True, ax=axes[2], color='red')
axes[2].set_title('StandardScaler (Media 0, Desv 1)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Crea una gráfica de dispersión entre 'sepal length (cm)' y 'sepal width (cm)' con los datos escalados por StandardScaler.

# %%
plt.figure(figsize=(8, 6))

# Crear gráfica de dispersión usando los datos estandarizados
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=data_standard, color='purple', s=60)

#El origen es (0,0) para evidenciar la media 0
plt.axhline(0, color='black', linestyle='--', alpha=0.5) 
plt.axvline(0, color='black', linestyle='--', alpha=0.5)

plt.title("Dispersión con StandardScaler (sepal length vs sepal width)")
plt.xlabel("Sepal Length (Estandarizado)")
plt.ylabel("Sepal Width (Estandarizado)")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### 4. ¿Qué técnica de escalado crees que es más adecuada para este conjunto de datos? ¿Por qué?

# %%
"""
1. StandardScaler: Es ideal cuando se requiere que los datos tengan una distribución centrada y escalada (media de 0 y desviación estándar de 1)[cite: 1]. Es muy adecuado para el dataset Iris si vamos a utilizar algoritmos sensibles a la escala como SVM, Regresión Logística o Análisis de Componentes Principales (PCA)[cite: 1].

2. MinMaxScaler: Es la técnica adecuada si el algoritmo exige que todas las variables entren en un rango uniforme específico sin distorsionar las distancias originales[cite: 1]. Esto es muy útil en algoritmos basados en distancias (como KNN) o redes neuronales artificiales[cite: 1].

Para el conjunto de datos Iris (que consta de medidas biológicas sin valores atípicos extremos), StandardScaler suele ser la opción más habitual y robusta como primer enfoque.
"""
